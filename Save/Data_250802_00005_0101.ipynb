# %%
# !pip install pandas numpy matplotlib seaborn scipy statsmodels scikit-learn openpyxl xlsxwriter ipython jupyter notebook
# Out:
# ...
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    -------- ------------------------------- 2.4/11.0 MB 12.3 MB/s eta 0:00:01
#    ------------------- -------------------- 5.2/11.0 MB 12.4 MB/s eta 0:00:01
#    ---------------------------- ----------- 7.9/11.0 MB 12.4 MB/s eta 0:00:01
#    ------------------------------------- -- 10.2/11.0 MB 12.4 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 11.3 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#    ------- -------------------------------- 2.4/12.8 MB 12.0 MB/s eta 0:00:01
#    --------------- ------------------------ 5.0/12.8 MB 12.2 MB/s eta 0:00:01
#    ----------------------- ---------------- 7.6/12.8 MB 12.3 MB/s eta 0:00:01
#    ------------------------------- -------- 10.2/12.8 MB 12.3 MB/s eta 0:00:01
#    ---------------------------------------  12.6/12.8 MB 12.3 MB/s eta 0:00:01
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import statsmodels.api as sm
# 그래프 한글폰트 깨짐 방지 (선택)
plt.rcParams['font.family'] = 'Malgun Gothic'  # Windows 기준
plt.rcParams['axes.unicode_minus'] = False
print("📊 패키지 불러오기 완료!")
# Out:
# 📊 패키지 불러오기 완료!

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/delic1758/K-Frailty/main/data/K-Frailty.csv"
df = pd.read_csv(url)
df.head()
# Out:
# C:\Users\SM\AppData\Local\Temp\ipykernel_15556\3792896287.py:4: DtypeWarning: Columns (311,428,490,491,492,493,494,495,496,497,498,499) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(url)
#         PID   seqNo  surveyNoR  ANS_TYPE ANS_SUB1 ANS_SUB2  ANS2_TYPE  \
# 0  159330$1  159330      39005         0                            2
# 1  159313$1  159313      39005         0                            2
# 2  159329$1  159329      39005         0                            2
# 3  159335$1  159335      39005         0                            2
# 4  159425$1  159425      39006         0                            1
#
#   ANS2_SUB  A11_1  A11_2  ...  T나이_3  T혼인상태  THTYPE  T교육수준  T취업여부  \
# 0               1      1  ...      4      2       1      2      2
# 1               1      1  ...      3      2       1      4      2
# 2               1      1  ...      1      2       1      3      1
# ...

# %%
# ---------------- 요약 정보 출력 ----------------
print("✅ 데이터 기본 정보")
print("-" * 50)
print(f"🔹 행 개수: {df.shape[0]}")
print(f"🔹 열 개수: {df.shape[1]}")
print("\n🔹 열별 결측값 개수 (상위 20개)")
print(df.isnull().sum().sort_values(ascending=False).head(20))
print("\n🔹 열별 데이터 타입")
print(df.dtypes.value_counts())
print(df.dtypes.head(10))  # 상위 10개만 미리 보기
print("\n🔹 기본 통계 요약 (숫자형)")
print(df.describe().T.head(10))  # 상위 10개 요약
# Out:
# ✅ 데이터 기본 정보
# --------------------------------------------------
# 🔹 행 개수: 10078
# 🔹 열 개수: 784
#
# 🔹 열별 결측값 개수 (상위 20개)
# PID          0
# seqNo        0
# surveyNoR    0
# ANS_TYPE     0
# ANS_SUB1     0
# ANS_SUB2     0
# ANS2_TYPE    0
# ANS2_SUB     0
# A11_1        0
# A11_2        0
# A11_3        0
# HTYPE        0
# S6_1         0
# S6_2         0
# S6_3         0
# S6_4         0
# S6_5         0
# A10_1        0
# A10_2        0
# RES_HNO      0
# dtype: int64
#
# 🔹 열별 데이터 타입
# int64      692
# object      90
# float64      2
# Name: count, dtype: int64
# PID          object
# seqNo         int64
# surveyNoR     int64
# ANS_TYPE      int64
# ANS_SUB1     object
# ANS_SUB2     object
# ANS2_TYPE     int64
# ANS2_SUB     object
# A11_1         int64
# A11_2         int64
# dtype: object
#
# 🔹 기본 통계 요약 (숫자형)
#              count           mean           std       min        25%  \
# seqNo      10078.0  135529.402064  34911.567253  100012.0  116974.75
# ...

# %%
# -----------------자동 저장 (로컬 + GitHub) + Git push -----------------
import os
import shutil
import re
from datetime import datetime

notebook_filename = "Data_250802_00006_0054.ipynb"  # ← 실제 파일명 입력
now = datetime.now()
date_str = now.strftime('%y%m%d')
time_str = now.strftime('%H%M')
base_name = f"Data_{date_str}"
num_str = ""
# 저장 경로 설정
local_save = os.path.join("C:\\Users\\SM\\Desktop\\K-Frailty", "Save")  # 로컬
github_save = "Save"  # 깃허브 추적 폴더

# 번호 자동 증가 함수
def get_next_num(path):
    existing = [f for f in os.listdir(path) if f.startswith(base_name) and f.endswith(".ipynb")]
    nums = [int(re.search(rf"{base_name}_(\d{{5}})_\d{{4}}\.ipynb", f).group(1))
            for f in existing if re.search(rf"{base_name}_(\d{{5}})_\d{{4}}\.ipynb", f)]
    return f"{(max(nums) + 1) if nums else 1:05}"

# ---------- 로컬 저장 ----------
num_str = get_next_num(local_save)
new_filename = f"{base_name}_{num_str}_{time_str}.ipynb"
os.makedirs(local_save, exist_ok=True)

if os.path.exists(notebook_filename):
    local_path = os.path.join(local_save, new_filename)
    shutil.copy2(notebook_filename, local_path)
    print(f"✅ 로컬 저장 완료: {local_path}")
else:
    print(f"❌ 로컬 저장 실패: 파일을 찾을 수 없습니다: {notebook_filename}")

# ---------- GitHub 저장 ----------
num_str = get_next_num(github_save)
new_filename = f"{base_name}_{num_str}_{time_str}.ipynb"
os.makedirs(github_save, exist_ok=True)

if os.path.exists(notebook_filename):
    github_path = os.path.join(github_save, new_filename)
    shutil.copy2(notebook_filename, github_path)
    print(f"✅ GitHub용 저장 완료: {github_path}")
    
    # Git에 반영 (add → commit → push)
    subprocess.run(["git", "add", "Save/"])
    subprocess.run(["git", "commit", "-m", f"Backup: {new_filename}"])
    subprocess.run(["git", "push", "origin", "main"])
else:
    print(f"❌ GitHub 저장 실패: 파일을 찾을 수 없습니다: {notebook_filename}")
# Out:
# ❌ 로컬 저장 실패: 파일을 찾을 수 없습니다: Data_250802_00006_0054
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 37
#      34     print(f"❌ 로컬 저장 실패: 파일을 찾을 수 없습니다: {notebook_filename}")
#      36 # ---------- GitHub 저장 ----------
# ---> 37 num_str = get_next_num(github_save)
#      38 new_filename = f"{base_name}_{num_str}_{time_str}.ipynb"
#      39 os.makedirs(github_save, exist_ok=True)
#
# Cell In[1], line 19, in get_next_num(path)
#      18 def get_next_num(path):
# ---> 19     existing = [f for f in os.listdir(path) if f.startswith(base_name) and f.endswith(".ipynb")]
#      20     nums = [int(re.search(rf"{base_name}_(\d{{5}})_\d{{4}}\.ipynb", f).group(1))
#      21             for f in existing if re.search(rf"{base_name}_(\d{{5}})_\d{{4}}\.ipynb", f)]
#      22     return f"{(max(nums) + 1) if nums else 1:05}"
#
# ...
